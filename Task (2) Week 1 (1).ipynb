# %% [markdown]
# ## Objective
# * The objective of this exercise is to explore and visualize the Traffic Index dataset to gain insights and understand the patterns in the data.

# %% [markdown]
# ##Dataset Description

# %% [markdown]
# | Column Name | Description | Data Type |
# | :---------------- | :------: | ----: |
# |   City  |   Name of the city	   | Object |
# | Datetime           |   Date and time of the data entry	   | Object |
# |  TrafficIndexLive    |  Real-time traffic index	   | Int |
# |  Jamscount |  Number of traffic jams	   | Int |
# |   JamsDelay  |   Total delay caused by traffic jams (in minutes)	   | Float |
# |JamsLength           |   Total length of traffic jams (in kilometers)	   | Float |
# |  TrafficIndexWeekAgo    |  Traffic index one week ago	   | Int |
# |  TravelTimeHistoric |  Historical average travel time (in minutes)	   | Float |
# |   TravelTimeLive  |   Real-time travel time (in minutes)	   | Float |

# %% [markdown]
# # Tasks

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)

# %%
import pandas as pd
df = pd.read_csv('/content/Task (2) Dataset.csv')
df.head()
# Out:
#        City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 0  Abudhabi  2023-07-07 08:01:30                 6          4       15.6
# 1  Abudhabi  2023-07-07 09:01:30                 7          7       20.5
# 2  Abudhabi  2023-07-07 10:46:30                 7          8       25.0
# 3  Abudhabi  2023-07-07 11:16:30                 8         11       30.6
# 4  Abudhabi  2023-07-07 12:01:30                 8         20       62.1
#
#    JamsLength  TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# 0         0.7                 13.0           59.611918       54.803617
# 1         1.7                  8.0           60.221387       56.118629
# 2         2.8                  6.0           59.161978       55.518834
# 3         5.5                  6.0           59.738138       56.413917
# 4         6.5                  5.0           58.958314       56.059246

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40878 entries, 0 to 40877
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 40878 non-null  object
#  1   Datetime             40878 non-null  object
#  2   TrafficIndexLive     40878 non-null  int64
#  3   JamsCount            40878 non-null  int64
#  4   JamsDelay            40878 non-null  float64
#  5   JamsLength           40878 non-null  float64
#  6   TrafficIndexWeekAgo  40877 non-null  float64
#  7   TravelTimeHistoric   38558 non-null  float64
#  8   TravelTimeLive       38558 non-null  float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 2.8+ MB

# %%
df.describe()
# Out:
#        TrafficIndexLive     JamsCount     JamsDelay    JamsLength  \
# count      40878.000000  40878.000000  40878.000000  40878.000000
# mean          14.045085     72.419150    273.997157     41.224013
# std           12.369340    110.159499    467.126318     74.198095
# min            0.000000      0.000000      0.000000      0.000000
# 25%            4.000000      8.000000     24.800000      2.800000
# 50%           11.000000     29.000000     94.000000     11.650000
# 75%           21.000000     86.000000    301.775000     43.100000
# max          138.000000   1359.000000   9989.400000   1173.900000
#
#        TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# count         40877.000000        38558.000000    38558.000000
# mean             13.942046           72.166931       71.528012
# std              12.326288           11.885860       12.322911
# min               0.000000           49.381346       46.723235
# 25%               4.000000           63.328053       61.769934
# 50%              11.000000           70.038204       70.675644
# 75%              21.000000           78.919754       78.855752
# max             138.000000          120.140593      134.484139

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
massing_values = df.isnull().sum()
print(massing_values)
# Out:
# City                      0
# Datetime                  0
# TrafficIndexLive          0
# JamsCount                 0
# JamsDelay                 0
# JamsLength                0
# TrafficIndexWeekAgo       1
# TravelTimeHistoric     2320
# TravelTimeLive         2320
# dtype: int64

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
sumary_stat=df.groupby('City').sum()
print(sumary_stat)
# Out:
#                                                    Datetime  TrafficIndexLive  \
# City
# Abudhabi  2023-07-07 08:01:302023-07-07 09:01:302023-07-...             41901
# Al-ain    2023-07-07 08:01:302023-07-07 09:01:302023-07-...             30732
# Cairo     2022-12-16 11:01:302022-12-16 12:01:302022-12-...             67005
# Dammam    2023-07-07 08:16:302023-07-07 09:01:302023-07-...             47929
# Doha      2022-12-16 12:46:302022-12-16 13:01:302022-12-...            143176
# Dubai     2022-12-16 13:01:302022-12-16 14:16:302022-12-...            196581
# Jeddah    2023-07-07 08:01:302023-07-07 09:01:302023-07-...             46811
#
#           JamsCount  JamsDelay  JamsLength  TrafficIndexWeekAgo  \
# City
# Abudhabi     115421   416540.3     55287.2              41494.0
# Al-ain        26421    87351.8      8701.2              30514.0
# Cairo        567476  2338591.2    346394.8              67499.0
# Dammam       130124   475552.2     77270.9              46798.0
# Doha         364277  1109204.0    122420.4             142598.0
# Dubai       1609530  6233031.6    970006.7             195753.0
# Jeddah       147101   540184.7    105074.0              45253.0
#
#           TravelTimeHistoric  TravelTimeLive
# City
# Abudhabi       229060.225694   224854.001917
# Al-ain         244393.175008   240413.255839
# Cairo          704179.683894   675835.063068
# Dammam         257783.301274   255555.979974
# Doha           603790.904673   604946.043385
# Dubai          515351.334199   531340.083300
# Jeddah         228053.896524   225032.666332

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Traffic_Index, Date).

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(4, 6))
sns.histplot(df['TrafficIndexLive'], bins=20, kde=True)
plt.title('Distribution of Traffic Index')
plt.xlabel('Traffic Index')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Traffic_Index vs. Weather_Condition).

# %% [markdown]
# ## 2. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %% [markdown]
# ## 3. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>
